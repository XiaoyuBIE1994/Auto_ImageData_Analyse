# %%
from launch import *
# %matplotlib inline

res = launch()
# Out:
# INFO: 10 RANSAC iteration finished
# R: rerun, others: continue
#
# X : ['0', '423.0'], Y: ['-0.11', ''], Peak Value: 1.72
# OCR Check, if right, press Enter, if not, please enter its index and true value
# Enter A to abandon direcly
# OCR correction: 3 0.27
#
# X : ['0', '423.0'], Y: ['-0.11', '0.27'], Peak Value: 1.72
# OCR Check, if right, press Enter, if not, please enter its index and true value
# Enter A to abandon direcly
# OCR correction:
# INFO: The mean and variance for the first intersection point are:(2096.37, 1.488) and (257.984, 0.002)
# INFO: The mean and variance for the second intersection point are:(2100.282, 1.72) and (342.61, 0.0)
# =============Resualt=============
#
#
# The origin of coordinate is: (63, 266)
# The firs marker in X axis is: (141, 266)
# The second marker in y axis is: (63, 165)
# The distance of every tick mark in X axis is 78 pixel
# The distance of every tick mark in y axis is 50.5 pixel
# The scale in x axis is: ['0', '423.0']
# ...
