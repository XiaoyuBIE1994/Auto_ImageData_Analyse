# %%
from launch import *
# %matplotlib inline

res = launch()
# Out:
# R: rerun, others: continue
#
# X : ['0', '409.0'], Y: ['-0.15', '0.24'], Peak Value: 1.74
# OCR Check, if right, press Enter, if not, please enter its index and true value
# Enter A to abandon direcly
# OCR correction:
# =============Resualt=============
#
#
# The origin of coordinate is: (67, 266)
# The firs marker in X axis is: (145, 266)
# The second marker in y axis is: (67, 165)
# The distance of every tick mark in X axis is 78 pixel
# The distance of every tick mark in y axis is 50.5 pixel
# The scale in x axis is: ['0', '409.0']
# The scale in y axis is: ['-0.15', '0.24']
# The x scale is 5.244/pixel
# The y scale is 0.00772/pixel
# Line 1 is: y = -0.424x + 263.911
# Line 2 is: y = -86.750x + 39245.500
# The first point is: (2016.49, 1.345)
# The second point is: (2019.598, 1.74)
#
#
# =============Finish=============
# E: exit, S: save and exit, A: abandon result, others: continue
# E
