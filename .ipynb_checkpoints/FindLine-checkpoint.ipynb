# %%
import Intergration
import Exchange
import numpy as np
import os
import shutil
from IPython.display import clear_output

# %% [markdown]
# # Params for new image (larger)

# %%
# Load data
# localpath = "E:\Faurecia\Data"
workpath = r"D:\PFE_Xue\04-Mise_en_oeuvre_essais\99-Archive"
localpath = workpath + "\Image_Data_large"
abandon_dir = workpath + "\Abandon"
traite_dir = workpath + "\DEJA_traites"

# configuration
data_color_range = [60, 160, 160, 210, 130, 200]
start_ratio = 0.5
vert_ratio_num = 0.5
vert_ratio_gap=0.8

ransac_params = {"max_iter": 10000, "mean_iter":10, \
                 "line1_gap":50, "line1_cut_range":0.2, "line1_k_min":-1,  "line1_k_max":0.05,\
                 "line2_gap":5, "line2_cut_range":0.90, "line2_k_max":-10}

find_corner_params = {"color_range":[0, 100, 0, 100, 0, 100], \
                      "X_search_range":4, \
                      "y_search_range":4}

ocr_params = {"scale_w":2, "scale_h":2, "sharpen_lower":175, "sharpen_upper":255, \
              "kernel": np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]], np.float32) }

find_mark_params = {"SHOW_MARK":False, "thr": 170, "search_range":10, \
                    "bb_size_X":(12,1), "jug_cond_X":5, \
                    "bb_size_Y":(1,12), "jug_cond_Y":5}

find_coor_params = {"SHOW_COOR":False, "bias_w_x":-20, "bias_h_x":8, "img_w_x":40, "img_h_x":30, \
                    "bias_w_y":-50, "bias_h_y":-10, "img_w_y":45, "img_h_y":20, "ocr_params":ocr_params}

find_peak_params = {"SHOW_PEAK":False, \
                    "bias_w_l":5, "bias_w_r":-50, "bias_h":2, "img_w":30, "img_h":60, \
                    "x_thr":15, "y_thr":100, "color_range":[0,180,0,180,0,180],\
                    "ocr_params":ocr_params}

SHOW_RANSAC_LINE = True
CHECK_RESULT = True
MODE_CHECK = False
SHOW_RESULT = True

# %% [markdown]
# # Params for old images (smaller)

# %%
# Load data
# localpath = "E:\Faurecia\Data"
# localpath = "E:\Faurecia\Treatment_Data\Image_Data_small"
# abandon_dir = r"E:\Faurecia\Abandon\small"
# abandon_dir= r"E:\Faurecia\Data\SB_T85_V&Plate_LGF20"
workpath = r"D:\PFE_Xue\04-Mise_en_oeuvre_essais\99-Archive"
localpath = workpath + "\Photo_a_traiter"
# print (localpath)
abandon_dir = workpath + "\Abandon"
traite_dir = workpath + "\DEJA_traites"

# configuration
data_color_range = [60, 160, 160, 210, 130, 200]
start_ratio = 0.5
vert_ratio_num = 0.2
vert_ratio_gap=0.8

ransac_params = {"max_iter": 10000, "mean_iter":10, \
                 "line1_gap":50, "line1_cut_range":0.2, "line1_k_min":-1, "line1_k_max":0.05, \
                 "line2_gap":5, "line2_cut_range":0.90, "line2_k_max":-10}

find_corner_params = {"color_range":[0, 100, 0, 100, 0, 100], \
                      "X_search_range":4, \
                      "y_search_range":4}

ocr_params = {"scale_w":2, "scale_h":2, "sharpen_lower":160, "sharpen_upper":255, \
              "kernel": np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]], np.float32) }

find_mark_params = {"SHOW_MARK":False, "thr": 170, "search_range":10, \
                    "bb_size_X":(12,1), "jug_cond_X":5, \
                    "bb_size_Y":(1,12), "jug_cond_Y":5}

find_coor_params = {"SHOW_COOR":False, "bias_w_x":-20, "bias_h_x":8, "img_w_x":30, "img_h_x":14, \
                    "bias_w_y":-32, "bias_h_y":-7, "img_w_y":30, "img_h_y":14, "ocr_params":ocr_params}

find_peak_params = {"SHOW_PEAK":False, "scale_w":2, "scale_h":2, \
                    "bias_w_l":5, "bias_w_r":-50, "bias_h":2, "img_w":30, "img_h":30, \
                    "x_thr":12, "y_thr":50, "color_range":[0,180,0,180,0,180],\
                    "ocr_params":ocr_params}

SHOW_RANSAC_LINE = True
CHECK_RESULT = True
MODE_CHECK = True
SHOW_RESULT = True

# %% [markdown]
# # Loop Run

# %%
peakvalue = Exchange.import_peak(workpath)
result_dir = loop_run(localpath, workpath, abandon_dir, traite_dir, peakvalue)
# Out:
# R: rerun, others: continue:
#
# X : ['0', '323.0'], Y: ['-0.1', '0.24'], Peak Value: 1.54
# OCR Check, if right, press Enter, if not, please enter its index and true value
# Enter A to abandon direcly
# OCR correction: 0 1
#
# X : ['1.0', '323.0'], Y: ['-0.1', '0.24'], Peak Value: 1.54
# OCR Check, if right, press Enter, if not, please enter its index and true value
# Enter A to abandon direcly
# OCR correction: 0 0
#
# X : ['0.0', '323.0'], Y: ['-0.1', '0.24'], Peak Value: 1.54
# OCR Check, if right, press Enter, if not, please enter its index and true value
# Enter A to abandon direcly
# OCR correction:
# =============Resualt=============
#
#
# The origin of coordinate is: (54, 248)
# The firs marker in X axis is: (128, 248)
# The second marker in y axis is: (54, 151)
# The distance of every tick mark in X axis is 74 pixel
# The distance of every tick mark in y axis is 48.5 pixel
# The scale in x axis is: ['0.0', '323.0']
# The scale in y axis is: ['-0.1', '0.24']
# The x scale is 4.365/pixel
# The y scale is 0.00701/pixel
# Line 1 is: y = -0.122x + 205.650
# Line 2 is: y = -17.744x + 7492.952
# The first point is: (1569.386, 0.551)
# The second point is: (1604.089, 1.54)
#
#
# =============Finish=============

# %%
def loop_run(localpath, workpath, abandon_dir, traite_dir, peakvalue):
    result_dir = {}
    if not os.path.isdir(abandon_dir):
        os.mkdir(abandon_dir)
    if not os.path.isdir(traite_dir):
        os.mkdir(traite_dir)
    for subdir, dirs, files in os.walk(localpath):
        for file in files:
            if ".PNG" in file:
                filename = file
#                 print (peakvalue[filename[:-4]])
                imagepath = os.path.join(subdir, file)
#                 print (imagepath)
                result = Intergration.model_run (imagepath, data_color_range, start_ratio, vert_ratio_num, vert_ratio_gap, \
                                               ransac_params, find_corner_params, find_mark_params, find_coor_params, \
                                               find_peak_params,\
                                               MODE_CHECK, SHOW_RANSAC_LINE, CHECK_RESULT, SHOW_RESULT, peakvalue)
                if result == {}:
                    copy_path = os.path.join(abandon_dir, file)
                    shutil.move(imagepath, copy_path)
                    data_in = input("Error: Auto detection fail, press E to exit, others to continue")
                    if data_in == "E":
                        clear_output()
                        return result_dir
                    else:
                        clear_output()
                        continue

                data_in = input("E: exit, S: save and exit, A: abandon result, others: continue\n")
                if data_in == "E":
                    return result_dir
                elif data_in == "S":
                    result_dir[filename[:-4]] = result
                    write = Exchange.export_result(filename, workpath, result)
                    copy_path = os.path.join(traite_dir, file)
                    shutil.move(imagepath, copy_path)
                    return result_dir
                elif data_in == "A":
                    pt1 = ()
                    pt2 = ()
                    copy_path = os.path.join(abandon_dir, file)
#                     shutil.copy(imagepath, copy_path)
                    shutil.move(imagepath, copy_path)
                else:
                    write = Exchange.export_result(filename, workpath, result)
                    result_dir[filename[:-4]] = result
                    copy_path = os.path.join(traite_dir, file)
                    shutil.move(imagepath, copy_path)
                clear_output()
    return result_dir
